# %%
import numpy as np 
import pandas as pd
import warnings
import matplotlib.pyplot as plt 
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('data_train.csv', sep=',', decimal='.')
#df = pd.get_dummies(df, columns=['Vehicle_Age'], drop_first=False, dummy_na=False)
df = df.drop(columns=['id','Region_Code'])
df
# Out:
#         Gender  Age  Driving_License  Previously_Insured Vehicle_Age  \
# 0       Female   45                1                   0    1-2 Year
# 1         Male   25                1                   1    < 1 Year
# 2       Female   57                1                   1    1-2 Year
# 3         Male   50                1                   0    1-2 Year
# 4       Female   21                1                   0    < 1 Year
# ...        ...  ...              ...                 ...         ...
# 346071  Female   37                1                   0    1-2 Year
# 346072    Male   54                1                   0   > 2 Years
# 346073  Female   25                1                   1    < 1 Year
# 346074    Male   22                1                   1    < 1 Year
# 346075    Male   65                1                   0    1-2 Year
#
#        Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# ...

# %%
df['Gender'] = df['Gender'].map({'Male': 1,'Female': 0})
df['Vehicle_Damage'] = df['Vehicle_Damage'].map({'Yes': 1,'No': 0})
df['Vehicle_Age'] = df['Vehicle_Age'].map({'< 1 Year': 1,'1-2 Year': 2,'> 2 Years': 3})

# %%
df.shape
# Out:
# (346076, 10)

# %%
df.head(10)
# Out:
#    Gender  Age  Driving_License  Previously_Insured  Vehicle_Age  \
# 0       0   45                1                   0            2
# 1       1   25                1                   1            1
# 2       0   57                1                   1            2
# 3       1   50                1                   0            2
# 4       0   21                1                   0            1
# 5       0   31                1                   1            1
# 6       1   52                1                   0            2
# 7       1   42                1                   0            2
# 8       1   43                1                   0            2
# 9       1   32                1                   0            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1         21406.0                 124.0       22         0
# 1               0         58078.0                 152.0       86         0
# ...

# %%
X = df.iloc[:,0:9]
Y = df.iloc[:, 9]

# %%
print("Poucentage de Non Favorable: {0:3f}".format(100*sum(Y==0) / len(Y)))
print("Poucentage de Favorable: {0:3f}".format(100*sum(Y==1) / len(Y)))
# Out:
# Poucentage de Non Favorable: 96.625886
# Poucentage de Favorable: 3.374114

# %%
X_normal = X.loc[df['Response'] == 0]

# %%
X_normal = X[Y==0]

# %%
idx=list(idx)

# %%
idx
# Out:
# [104703,
#  133861,
#  259778,
#  110243,
#  143322,
#  103411,
#  260197,
#  26716,
#  159229,
#  193340,
#  90093,
#  83657,
#  90267,
#  240171,
#  2412,
#  304432,
#  238247,
#  107199,
#  261267,
#  194805,
#  100008,
#  36451,
#  120284,
#  40430,
#  266360,
#  165810,
#  176218,
#  96544,
#  222920,
#  98249,
#  62810,
#  279598,
#  168997,
#  219133,
#  126899,
#  228992,
#  184927,
#  259850,
#  102087,
#  218370,
#  108339,
#  65065,
#  185321,
#  290795,
#  317594,
#  83247,
#  212162,
#  42489,
#  315314,
#  159902,
#  269776,
#  303597,
#  225375,
#  117174,
#  263440,
#  42970,
#  80488,
#  311534,
#  142829,
#  313441,
#  256274,
#  297722,
#  138944,
#  210335,
#  208752,
#  233729,
#  240143,
#  31208,
#  286601,
#  182154,
#  280380,
#  6742,
#  218314,
#  265387,
#  109021,
#  318924,
#  163337,
#  57741,
#  305969,
#  308570,
#  314952,
#  131586,
#  215037,
#  282888,
#  209630,
#  101060,
#  92793,
#  271126,
#  236933,
#  231434,
#  23564,
#  313553,
# ...

# %%
 X_normal.iloc[idx,:]
# Out:
#         Gender  Age  Driving_License  Previously_Insured  Vehicle_Age  \
# 108327       0   26                1                   1            1
# 138478       0   24                1                   0            1
# 268864       1   59                1                   1            2
# 114081       1   72                1                   0            2
# 148288       1   46                1                   0            1
# ...        ...  ...              ...                 ...          ...
# 49576        0   22                1                   0            1
# 176402       0   23                1                   1            1
# 249720       1   62                1                   1            2
# 205489       1   44                1                   0            3
# 229337       1   21                1                   1            1
#
#         Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# ...

# %%
Y_normal = Y[Y==0]

# %%
Y_normal
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 346071    0
# 346072    0
# 346073    0
# 346074    0
# 346075    0
# Name: Response, Length: 334399, dtype: int64

# %%
idx = np.random.randint(len(X_normal), size=25000)

# %%
idx
# Out:
# array([4318, 7672, 7852, ..., 3565, 2771, 8143])

# %%
X_normal
# Out:
#         Gender  Age  Driving_License  Previously_Insured  Vehicle_Age  \
# 0            0   45                1                   0            2
# 1            1   25                1                   1            1
# 2            0   57                1                   1            2
# 3            1   50                1                   0            2
# 4            0   21                1                   0            1
# ...        ...  ...              ...                 ...          ...
# 346071       0   37                1                   0            2
# 346072       1   54                1                   0            3
# 346073       0   25                1                   1            1
# 346074       1   22                1                   1            1
# 346075       1   65                1                   0            2
#
#         Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# ...

# %%
X_normal
# Out:
#         Gender  Age  Driving_License  Previously_Insured  Vehicle_Age  \
# 0            0   45                1                   0            2
# 1            1   25                1                   1            1
# 2            0   57                1                   1            2
# 3            1   50                1                   0            2
# 4            0   21                1                   0            1
# ...        ...  ...              ...                 ...          ...
# 346071       0   37                1                   0            2
# 346072       1   54                1                   0            3
# 346073       0   25                1                   1            1
# 346074       1   22                1                   1            1
# 346075       1   65                1                   0            2
#
#         Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# ...

# %%
X_normal = X[Y==0]
#idx = np.random.randint(len(X_normal), size=10000)
X_normal =  X_normal.iloc[idx,:]
Y_normal = Y[Y==0]
Y_normal = Y_normal.iloc[idx]

X_fraude = X[Y==1]
Y_fraude = Y[Y==1]

# %%
Y_fraude
# Out:
# 74        1
# 80        1
# 185       1
# 188       1
# 230       1
#          ..
# 345980    1
# 345987    1
# 345999    1
# 346000    1
# 346035    1
# Name: Response, Length: 11677, dtype: int64

# %%
X_reduce = np.concatenate((X_normal, X_fraude), axis=0)
Y_reduce = np.concatenate((Y_normal, Y_fraude), axis=0)

# %%
X_reduce.shape
# Out:
# (36677, 9)

# %%
print("Poucentage de Non Favorable: {0:3f}".format(100*sum(Y_reduce==0) / len(Y_reduce)))
print("Poucentage de Favorable: {0:3f}".format(100*sum(Y_reduce==1) / len(Y_reduce)))
# Out:
# Poucentage de Non Favorable: 68.162609
# Poucentage de Favorable: 31.837391

# %%
from sklearn.ensemble import IsolationForest

# %%
IF=IsolationForest(n_estimators=2000)
IF.fit(X_reduce)
decision=IF.decision_function(X_reduce)
plt.figure(figsize=(8, 6))
plt.hist(decision, bins=50);

# %%
deicisionfinale=np.copy(decision)
deicisionfinale[decision<-0.15]=1
deicisionfinale[decision>=-0.05]=0

# %%
deicisionfinale = deicisionfinale.astype('int')

# %%
deicisionfinale
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
Y_reduce
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_reduce,deicisionfinale)
# Out:
# array([[24980,    20],
#        [11676,     1]], dtype=int64)
